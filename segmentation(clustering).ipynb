# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("Customer Data.csv")
df
# Out:
#      CUST_ID      BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0     C10001    40.900749           0.818182      95.40              0.00
# 1     C10002  3202.467416           0.909091       0.00              0.00
# 2     C10003  2495.148862           1.000000     773.17            773.17
# 3     C10004  1666.670542           0.636364    1499.00           1499.00
# 4     C10005   817.714335           1.000000      16.00             16.00
# ...      ...          ...                ...        ...               ...
# 8945  C19186    28.493517           1.000000     291.12              0.00
# 8946  C19187    19.183215           1.000000     300.00              0.00
# 8947  C19188    23.398673           0.833333     144.40              0.00
# 8948  C19189    13.457564           0.833333       0.00              0.00
# 8949  C19190   372.708075           0.666667    1093.25           1093.25
#
#       INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# ...

# %%
df.shape
# Out:
# (8950, 18)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8950 entries, 0 to 8949
# Data columns (total 18 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   CUST_ID                           8950 non-null   object
#  1   BALANCE                           8950 non-null   float64
#  2   BALANCE_FREQUENCY                 8950 non-null   float64
#  3   PURCHASES                         8950 non-null   float64
#  4   ONEOFF_PURCHASES                  8950 non-null   float64
#  5   INSTALLMENTS_PURCHASES            8950 non-null   float64
#  6   CASH_ADVANCE                      8950 non-null   float64
#  7   PURCHASES_FREQUENCY               8950 non-null   float64
#  8   ONEOFF_PURCHASES_FREQUENCY        8950 non-null   float64
#  9   PURCHASES_INSTALLMENTS_FREQUENCY  8950 non-null   float64
#  10  CASH_ADVANCE_FREQUENCY            8950 non-null   float64
# ...

# %%
df.describe()
# Out:
#             BALANCE  BALANCE_FREQUENCY     PURCHASES  ONEOFF_PURCHASES  \
# count   8950.000000        8950.000000   8950.000000       8950.000000
# mean    1564.474828           0.877271   1003.204834        592.437371
# std     2081.531879           0.236904   2136.634782       1659.887917
# min        0.000000           0.000000      0.000000          0.000000
# 25%      128.281915           0.888889     39.635000          0.000000
# 50%      873.385231           1.000000    361.280000         38.000000
# 75%     2054.140036           1.000000   1110.130000        577.405000
# max    19043.138560           1.000000  49039.570000      40761.250000
#
#        INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# count             8950.000000   8950.000000          8950.000000
# mean               411.067645    978.871112             0.490351
# std                904.338115   2097.163877             0.401371
# min                  0.000000      0.000000             0.000000
# ...

# %%
df.isnull().sum()
# Out:
# CUST_ID                               0
# BALANCE                               0
# BALANCE_FREQUENCY                     0
# PURCHASES                             0
# ONEOFF_PURCHASES                      0
# INSTALLMENTS_PURCHASES                0
# CASH_ADVANCE                          0
# PURCHASES_FREQUENCY                   0
# ONEOFF_PURCHASES_FREQUENCY            0
# PURCHASES_INSTALLMENTS_FREQUENCY      0
# CASH_ADVANCE_FREQUENCY                0
# CASH_ADVANCE_TRX                      0
# PURCHASES_TRX                         0
# CREDIT_LIMIT                          1
# PAYMENTS                              0
# MINIMUM_PAYMENTS                    313
# PRC_FULL_PAYMENT                      0
# TENURE                                0
# dtype: int64

# %%
df["MINIMUM_PAYMENTS"] = df["MINIMUM_PAYMENTS"].fillna(df["MINIMUM_PAYMENTS"].median())
df["CREDIT_LIMIT"] = df["CREDIT_LIMIT"].fillna(df["CREDIT_LIMIT"].median())

# %%
df.isnull().sum().sum()
# Out:
# 0

# %%
df.shape
# Out:
# (8950, 18)

# %%
df.isnull().sum()
# Out:
# CUST_ID                             0
# BALANCE                             0
# BALANCE_FREQUENCY                   0
# PURCHASES                           0
# ONEOFF_PURCHASES                    0
# INSTALLMENTS_PURCHASES              0
# CASH_ADVANCE                        0
# PURCHASES_FREQUENCY                 0
# ONEOFF_PURCHASES_FREQUENCY          0
# PURCHASES_INSTALLMENTS_FREQUENCY    0
# CASH_ADVANCE_FREQUENCY              0
# CASH_ADVANCE_TRX                    0
# PURCHASES_TRX                       0
# CREDIT_LIMIT                        0
# PAYMENTS                            0
# MINIMUM_PAYMENTS                    0
# PRC_FULL_PAYMENT                    0
# TENURE                              0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.drop(columns=["CUST_ID"],axis='columns',inplace=True)

# %%
df.columns
# Out:
# Index(['BALANCE', 'BALANCE_FREQUENCY', 'PURCHASES', 'ONEOFF_PURCHASES',
#        'INSTALLMENTS_PURCHASES', 'CASH_ADVANCE', 'PURCHASES_FREQUENCY',
#        'ONEOFF_PURCHASES_FREQUENCY', 'PURCHASES_INSTALLMENTS_FREQUENCY',
#        'CASH_ADVANCE_FREQUENCY', 'CASH_ADVANCE_TRX', 'PURCHASES_TRX',
#        'CREDIT_LIMIT', 'PAYMENTS', 'MINIMUM_PAYMENTS', 'PRC_FULL_PAYMENT',
#        'TENURE'],
#       dtype='object')

# %%
plt.figure(figsize=(14,14))
sns.heatmap(df.corr(), annot=True)
plt.show()

# %%
from sklearn.preprocessing import StandardScaler
scalar=StandardScaler()
scale_df = scalar.fit_transform(df)

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components=2)
pc = pca.fit_transform(scale_df)
pc_df = pd.DataFrame(data=pc ,columns=["PCA1","PCA2"])
pc_df
# Out:
#           PCA1      PCA2
# 0    -1.683648 -1.072244
# 1    -1.134081  2.509136
# 2     0.969389 -0.383558
# 3    -0.888221  0.004649
# 4    -1.600020 -0.683798
# ...        ...       ...
# 8945 -0.362572 -2.013435
# 8946 -0.580811 -1.675659
# 8947 -0.928985 -1.808047
# 8948 -2.337843 -0.653618
# 8949 -0.558028 -0.400644
#
# [8950 rows x 2 columns]

# %%
inertia = []
range_ = range(1,15)
for i in range_:
    kmeans = KMeans(n_clusters=i)
    kmeans.fit_predict(pd.DataFrame(scale_df))
    inertia.append(kmeans.inertia_)
plt.plot(range_,inertia,'co-')
plt.xlabel('K values') 
plt.ylabel('Inertia') 
plt.show()

# %%
from sklearn.cluster import KMeans
model=KMeans(3)
model.fit_predict(scale_df)
pc_df_kmeans= pd.concat([pc_df,pd.DataFrame({'cluster':model.labels_})],axis=1)

# %%
plt.figure(figsize=(10,10))
ax=sns.scatterplot(x="PCA1",y="PCA2",hue="cluster",data=pc_df_kmeans,palette=['cyan','green','blue'])
plt.show()

# %%
centers = pd.DataFrame(data=model.cluster_centers_,columns=[df.columns])

centers = scalar.inverse_transform(centers)
centers = pd.DataFrame(data=centers,columns=[df.columns])
centers
# Out:
#        BALANCE BALANCE_FREQUENCY    PURCHASES ONEOFF_PURCHASES  \
# 0  3990.939731          0.958493   384.802788       248.755226
# 1   799.771039          0.834870   503.555882       251.480912
# 2  2207.322227          0.981319  4250.652387      2708.000611
#
#   INSTALLMENTS_PURCHASES CASH_ADVANCE PURCHASES_FREQUENCY  \
# 0             136.125050  3867.144722            0.232917
# 1             252.396241   330.626335            0.464270
# 2            1543.134092   457.240008            0.948724
#
#   ONEOFF_PURCHASES_FREQUENCY PURCHASES_INSTALLMENTS_FREQUENCY  \
# 0                   0.110995                         0.144869
# 1                   0.131423                         0.345012
# 2                   0.668691                         0.741542
#
#   CASH_ADVANCE_FREQUENCY CASH_ADVANCE_TRX PURCHASES_TRX CREDIT_LIMIT  \
# 0               0.447385        12.393484      5.629073  6678.260993
# 1               0.068294         1.211293      8.627169  3268.129883
# ...

# %%
# Creating a target column "Cluster"
cluster_df = pd.concat([df,pd.DataFrame({'Cluster':model.labels_})],axis='columns')

# %%
cluster1_df = cluster_df[cluster_df["Cluster"]==0]
cluster2_df = cluster_df[cluster_df["Cluster"]==1]
cluster3_df = cluster_df[cluster_df["Cluster"]==2]
cluster3_df
# Out:
#           BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 6      627.260806           1.000000    7091.01           6402.63
# 12    1516.928620           1.000000    3217.99           2500.23
# 21    6369.531318           1.000000    6359.95           5910.04
# 34    3517.101616           0.727273     547.28              0.00
# 37    4047.480828           1.000000    2380.55           1642.17
# ...           ...                ...        ...               ...
# 8689   368.318662           0.909091    8053.95           8053.95
# 8698   873.680279           1.000000    2397.05           1072.46
# 8707    78.448912           1.000000    1875.18            977.85
# 8737  2533.618119           0.909091    5633.83           2985.92
# 8856   227.220411           1.000000    1387.60            288.54
#
#       INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 6                     688.38      0.000000             1.000000
# ...

# %%
sns.countplot(x='Cluster', data=cluster_df)
# Out:
# <AxesSubplot:xlabel='Cluster', ylabel='count'>

# %%
import joblib
joblib.dump(model, "model.pkl")
# Out:
# ['model.pkl']

# %%
cluster_df.to_csv("Customer_Data_with_clusters.csv")

# %%
from sklearn.model_selection import train_test_split
X = cluster_df.drop(['Cluster'],axis=1)
y= cluster_df[['Cluster']]
X_train, X_test, y_train, y_test =train_test_split(X, y, test_size=0.3)

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import classification_report
from sklearn import tree
from sklearn import metrics

clf_model= DecisionTreeClassifier(criterion="entropy")
clf_model.fit(X_train, y_train)
y_pred = clf_model.predict(X_test)

# %%
print(metrics.confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# [[ 421   36    5]
#  [  41 1792   29]
#  [  13   46  302]]
#               precision    recall  f1-score   support
#
#            0       0.89      0.91      0.90       462
#            1       0.96      0.96      0.96      1862
#            2       0.90      0.84      0.87       361
#
#     accuracy                           0.94      2685
#    macro avg       0.91      0.90      0.91      2685
# weighted avg       0.94      0.94      0.94      2685

# %%
import pickle
filename = 'classification_model.sav'
pickle.dump(clf_model, open(filename, 'wb'))

# %%
loaded_model = pickle.load(open(filename, 'rb'))
result = loaded_model.score(X_test, y_test)
print(result,'% Acuuracy')
# Out:
# 0.9366852886405959 % Acuuracy
